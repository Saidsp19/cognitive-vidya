# %% [markdown]
# # House Robber
# **Difficulty:** Medium | **Pattern:** Dynamic Programming
#
# Max money robbing houses without robbing two adjacent houses.

# %%
def rob(nums: list[int]) -> int:
    pass

# %%
# --- EVALUATION ENGINE ---
def evaluate():
    passed = 0
    total = 1

    test_cases = [([1,2,3,1], 4), ([2,7,9,3,1], 12), ([2,1,1,2], 4)]
    for i, case in enumerate(test_cases):
        *args, expected = case
        try:
            result = rob(*args) if len(args) > 1 else rob(args[0])
            if result == expected:
                passed += 1
                print(f"✅ Test {i+1} Passed")
            else:
                print(f"❌ Test {i+1} Failed. Expected {expected}, got {result}")
        except Exception as e:
            print(f"⚠️ Test {i+1} Error: {e}")

    if passed == total:
        print("\n🎉 ALL TESTS PASSED!")
    else:
        print(f"\n📊 Score: {passed}/{total} tests passed")

evaluate()
