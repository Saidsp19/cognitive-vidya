# %% [markdown]
# # Climbing Stairs
# **Difficulty:** Easy | **Pattern:** Dynamic Programming
#
# Count distinct ways to climb n stairs taking 1 or 2 steps at a time.

# %%
def climb_stairs(n: int) -> int:
    pass

# %%
# --- EVALUATION ENGINE ---
def evaluate():
    passed = 0
    total = 1

    test_cases = [(2, 2), (3, 3), (5, 8)]
    for i, case in enumerate(test_cases):
        *args, expected = case
        try:
            result = climb_stairs(*args) if len(args) > 1 else climb_stairs(args[0])
            if result == expected:
                passed += 1
                print(f"✅ Test {i+1} Passed")
            else:
                print(f"❌ Test {i+1} Failed. Expected {expected}, got {result}")
        except Exception as e:
            print(f"⚠️ Test {i+1} Error: {e}")

    if passed == total:
        print("\n🎉 ALL TESTS PASSED!")
    else:
        print(f"\n📊 Score: {passed}/{total} tests passed")

evaluate()
