# %% [markdown]
# # Container With Most Water
# **Difficulty:** Medium | **Pattern:** Two Pointers
#
# Find two lines that together with x-axis form a container holding most water.

# %%
def max_area(height: list[int]) -> int:
    pass

# %%
# --- EVALUATION ENGINE ---
def evaluate():
    passed = 0
    total = 1

    test_cases = [([1,8,6,2,5,4,8,3,7], 49), ([1,1], 1)]
    for i, case in enumerate(test_cases):
        *args, expected = case
        try:
            result = max_area(*args) if len(args) > 1 else max_area(args[0])
            if result == expected:
                passed += 1
                print(f"✅ Test {i+1} Passed")
            else:
                print(f"❌ Test {i+1} Failed. Expected {expected}, got {result}")
        except Exception as e:
            print(f"⚠️ Test {i+1} Error: {e}")

    if passed == total:
        print("\n🎉 ALL TESTS PASSED!")
    else:
        print(f"\n📊 Score: {passed}/{total} tests passed")

evaluate()
