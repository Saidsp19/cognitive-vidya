# %% [markdown]
# # Search Insert Position
# **Difficulty:** Easy | **Pattern:** Binary Search
#
# Find index of target in sorted array, or insert position if absent.

# %%
def search_insert(nums: list[int], target: int) -> int:
    pass

# %%
# --- EVALUATION ENGINE ---
def evaluate():
    passed = 0
    total = 1

    test_cases = [([1,3,5,6], 5, 2), ([1,3,5,6], 2, 1), ([1,3,5,6], 7, 4)]
    for i, case in enumerate(test_cases):
        *args, expected = case
        try:
            result = search_insert(*args) if len(args) > 1 else search_insert(args[0])
            if result == expected:
                passed += 1
                print(f"✅ Test {i+1} Passed")
            else:
                print(f"❌ Test {i+1} Failed. Expected {expected}, got {result}")
        except Exception as e:
            print(f"⚠️ Test {i+1} Error: {e}")

    if passed == total:
        print("\n🎉 ALL TESTS PASSED!")
    else:
        print(f"\n📊 Score: {passed}/{total} tests passed")

evaluate()
