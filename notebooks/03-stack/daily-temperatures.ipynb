# %% [markdown]
# # Daily Temperatures
# **Difficulty:** Medium | **Pattern:** Stack
#
# Return array where answer[i] is days until a warmer temperature.

# %%
def daily_temperatures(temps: list[int]) -> list[int]:
    pass

# %%
# --- EVALUATION ENGINE ---
def evaluate():
    passed = 0
    total = 1

    test_cases = [([73,74,75,71,69,72,76,73], [1,1,4,2,1,1,0,0]), ([30,40,50,60], [1,1,1,0])]
    for i, case in enumerate(test_cases):
        *args, expected = case
        try:
            result = daily_temperatures(*args) if len(args) > 1 else daily_temperatures(args[0])
            if result == expected:
                passed += 1
                print(f"✅ Test {i+1} Passed")
            else:
                print(f"❌ Test {i+1} Failed. Expected {expected}, got {result}")
        except Exception as e:
            print(f"⚠️ Test {i+1} Error: {e}")

    if passed == total:
        print("\n🎉 ALL TESTS PASSED!")
    else:
        print(f"\n📊 Score: {passed}/{total} tests passed")

evaluate()
